# %%
soma= 0
lista= ['joao', 'pedro', 'batista', 'joazinho','victor']
for i in lista:
  print(i)
# Out:
# joao
# pedro
# batista
# joazinho
# victor

# %%
lista= ['joao', 'pedro', 'batista', 'joazinho','victor']
lista.pop(3)
# Out:
# 'joazinho'

# %%
lista= [1,2,3,4,5]
lista_rev = lista[::-1]
print(lista)
# Out:
# [1, 2, 3, 4, 5]

# %%
livros= ['chapeuzinho vermelho', 'três porquinhos','lobo mau']
livros.sort()
print(livros)
# Out:
# ['chapeuzinho vermelho', 'lobo mau', 'três porquinhos']

# %%
m=[4,-1,7,-5,10,0]
m.sort()
print(m)
# Out:
# [-5, -1, 0, 4, 7, 10]

# %%
numeros=[1,2,4,7]
print(sum(numeros))
# Out:
# 14

# %%
quadrados= [x**2 for x in range(1,11)]
print(quadrados)
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100]

# %%
quadrado_tuplas=[(x,x**2)for x in range(1,6)]
print(quadrado_tuplas)
# Out:
# [(1, 1), (2, 4), (3, 9), (4, 16), (5, 25)]

# %%
palavras= ['python','é','legal']
uppercase=[word.upper() for word in palavras]
print(uppercase)
# Out:
# ['PYTHON', 'É', 'LEGAL']

# %%
meu_dicionario= {}
aluno = {
'nome':'João',
'idade': 25,
'curso': 'ciencia de dados',
'nota':{'matematica':90, 'historia':85, 'inglês': 88}
}
print("\ninterando sobre as chaves:")
for chave, valor in aluno.items():
  print(chave,":",valor)
# Out:
# interando sobre as chaves:
# nome : João
# idade : 25
# curso : ciencia de dados
# nota : {'matematica': 90, 'historia': 85, 'inglês': 88}

# %%
meu_dicionario= {}
aluno = {
'nome':'João',
'idade': 25,
'curso': 'ciencia de dados',
'nota':{'matematica':90, 'historia':85, 'inglês': 88}
}
print("\ninterando sobre as chaves:")
for disciplina, nota in aluno.items():
  print(disciplina,":",nota)
# Out:
# interando sobre as chaves:
# nome : João
# idade : 25
# curso : ciencia de dados
# nota : {'matematica': 90, 'historia': 85, 'inglês': 88}

# %%
turma_matematica={
1:{'nome': 'Marcos','nota':70},
2:{'nome': 'Maaria','nota':80},
3:{'nome': 'Manuel','nota':60},
4:{'nome': 'Miriam','nota':75}
}
for id in turma_matematica:
  print(turma_matematica[id]['nota'])
# Out:
# 70
# 80
# 60
# 75

# %%
lista= [-7,1,20,-4,5]
i= 0
while i < len(lista):
  print(f'{i}:{lista[i]}')
  i += 1
# Out:
# 0:-7
# 1:1
# 2:20
# 3:-4
# 4:5

# %%
lista= [-7,1,20,-4,5]
i= 0
for i in lista:
  print(f'{i}:{lista}')
  i+=1
# Out:
# -7:[-7, 1, 20, -4, 5]
# 1:[-7, 1, 20, -4, 5]
# 20:[-7, 1, 20, -4, 5]
# -4:[-7, 1, 20, -4, 5]
# 5:[-7, 1, 20, -4, 5]

# %%
for idx, item in enumerate(lista):
  print(f'{idx}:{item}')
# Out:
# 0:joao
# 1:pedro
# 2:batista
# 3:joazinho
# 4:victor
